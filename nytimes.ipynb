# %%
import requests
#import requests_ftp
import requests_cache
import lxml
import urllib2
from bs4 import BeautifulSoup
from collections import Counter
from matplotlib import pyplot as plt
import pandas as pd
plt.style.use('ggplot')
requests_cache.install_cache('coll_cache')
# %matplotlib inline

# %%
climreq = requests.get("https://www.nytimes.com/")
climhtml = climreq.text
clim = BeautifulSoup(climhtml, "lxml")
links = clim.find_all('h2', {'class': ['story-heading']})
# Out:
# [<h2 class="story-heading"><a href="https://www.nytimes.com/2017/02/25/us/ice-immigrant-deportations-trump.html">Agents Discover Freedom on Deportations Under Trump</a></h2>,
#  <h2 class="story-heading"><i class="icon"></i><a href="https://www.nytimes.com/2017/02/25/us/politics/travel-ban-nations-terror-risk.html">People From 7 Travel-Ban Nations Pose No Increased Terror Risk, Report Says</a></h2>,
#  <h2 class="story-heading"><a href="https://www.nytimes.com/2017/02/25/us/politics/dnc-perez-ellison-chairman-election.html">Democrats Elect <br/>Ex-Labor Secretary as Chairman</a></h2>,
#  <h2 class="story-heading"><a href="https://www.nytimes.com/2017/02/25/world/americas/wilbur-ross-trump-commerce-secretary.html">For Commerce Pick, \u2018Inherently Bad\u2019 Deals Paid Off</a></h2>,
#  <h2 class="story-heading"><a href="https://www.nytimes.com/2017/02/25/us/politics/trump-press-conflict.html">Trump Ruled Tabloid Media. Washington Is a Different Story.</a></h2>,
# ...

# %%
l = []
for i in range(0,len(links)):
    l.append(links[i].getText())
links = map(lambda s: s.strip(), l)

# %%
links = map(lambda s: s.encode("utf-8"))
links[0].encode("utf-8")
# Out:
# 'Agents Discover Freedom on Deportations Under Trump'

# %%
articles("http://www.cnn.com/index.html")
# Out:
# <!DOCTYPE html>\n<html class="no-js"><head><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><meta charset="unicode-escape"/><meta content="text/html" http-equiv="Content-Type"/><meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0" name="viewport"/><link href="/favicon.ie9.ico" rel="Shortcut Icon" type="image/x-icon"/><link href="//i.cdn.turner.com/cnn/.e/img/3.0/global/misc/apple-touch-icon.png" rel="apple-touch-icon" type="image/png"/><!--[if lte IE 9]><meta http-equiv="refresh" content="1;url=/2.4.0/static/unsupp.html" /><![endif]--><!--[if gt IE 9><!--><script>var CNN = CNN || {};CNN.pageTimer = {"interval":20,"isVisible":true,"pageType":"section","resetDelay":3,"resetThreshold":17,"sectionName":"homepage"};</script><!--<![endif]--><title>CNN - Breaking News, Latest News and Videos</title><meta content="homepage" name="section"/><meta content="2014-02-19T19:15:05Z" property="og:pubdate"/><meta content="2014-02-19T19:15:05Z" name="pubdate"/><meta co
# ...
